# %%
def average(numbers):
    return sum(numbers) / len(numbers)

numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

average = average(numbers)

print("The average of the numbers is:", average)

print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-537c7d3d453c> in <cell line: 4>()
#       2     return sum(numbers) / len(numbers)
#       3
# ----> 4 numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))
#       5
#       6 average = average(numbers)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
elements = input("Enter elements separated by spaces: ").split()

new_elements = []
for item in elements:
    if item not in new_elements:
        new_elements.append(item)

print("Duplicates are removed the list is:", new_elements)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6cdc9cc4dfca> in <cell line: 1>()
# ----> 1 elements = input("Enter elements separated by spaces: ").split()
#       2
#       3 new_elements = []
#       4 for item in elements:
#       5     if item not in new_elements:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
items = input("Enter numbers separated by spaces: ").split()

for item in items:
  if int(item) % 2 == 0:
    print(item)
# Out:
# Enter numbers separated by spaces: 1 2 3 4
# 2
# 4

# %%
even_number = list(range(100))
print(even_number[0:10:2])
# Out:
# [0, 2, 4, 6, 8]
